# %%
my_list = ["motor",1,"mobil", "toyota"]
my_list.append("suzuki")
print(my_list)
# Out:
# ['motor', 1, 'mobil', 'toyota', 'suzuki']

# %%
my_list = ["motor",1,"mobil", "toyota"]
my_list.append("suzuki")
my_list.remove(1)
my_list.insert(2,"Honda")
print(my_list)
# Out:
# ['motor', 'mobil', 'Honda', 'toyota', 'suzuki']

# %%
# tuple
my_tuple = (1,2,3,4)
print(my_tuple[1])
# Out:
# 2

# %%
my_dictionary = {
"nama" : "Akbar",
"nim" : "01234556",
"rombel" : "TI10"
}
print(my_dictionary["rombel"])
print(type("nim"))
print(type(my_dictionary))
# Out:
# TI10
# <class 'str'>
# <class 'dict'>

# %%
my_list = [1,2,3,4]
my_tuple = (1,2,3,4)
my_dictionary = {
"kendaraan"  : "motor",
"warna" : "putih"
}
print(type(my_list))
print(type(my_tuple))
print(type(my_dictionary))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>

# %%
my_list = [1,2,3,4,5,6,7,8]
my_list.append("hello")
my_listpop = my_list.pop(4)
print(my_list)
print(my_listpop)
# Out:
# [1, 2, 3, 4, 6, 7, 8, 'hello']
# 5

# %%
kontak= {"budi":"08382828", "ibu_budi":"08382828","Budi":"08382828"}
kontak["budi"]= "08382828"
print(kontak)
# Out:
# {'budi': '08382828', 'ibu_budi': '08382828', 'Budi': '08382828'}

# %%
kendaraan= ["beat karbu", "motor",200,"pink",2]
print(kendaraan)

kendaraan.append("13jt")
kendaraan.append("matic")
print(kendaraan)

kendaraan.insert(2, "honda")
print(kendaraan)

print(type(kendaraan))
print(type(kendaraan[0]))
print(type(kendaraan[1]))
print(type(kendaraan[2]))
print(type(kendaraan[3]))
print(type(kendaraan[4]))
print(type(kendaraan[5]))
print(type(kendaraan[6]))
print(type(kendaraan[7]))
# Out:
# ['beat karbu', 'motor', 200, 'pink', 2]
# ['beat karbu', 'motor', 200, 'pink', 2, '13jt', 'matic']
# ['beat karbu', 'motor', 'honda', 200, 'pink', 2, '13jt', 'matic']
# <class 'list'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>

# %%
prhitung_luas = int(input("""pilih salah satu:
1. hitung Luas persegi
2. hitung luas lingkaran
3. hitung luas segitiga
"""))

match hitung_luas:
    case 1:
        print("Menghitung luas persegi")
        sisi = int(input("Masukkan nilai sisi: "))
        hitung_luas_persegi = sisi ** 2
        print(f"Jadi luas persegi dengan sisi {sisi} cm adalah {hitung_luas_persegi} cm^2")
    case 2:
        print("menghitung luas lingkaran")
        r = int(input("Masukkan jari-jari lingkaran: "))
        luas = math.pi * r ** 2
        print(f"Luas lingkaran dengan jari-jari {r} adalah {luas}")
    case 3:
        print("menghitung luas lingkaran")
        def luas_segitiga(alas, tinggi):
             return 0.5 * alas * tinggi
        alas = int(input("Masukkan panjang alas segitiga: "))
        tinggi = int(input("Masukkan tinggi segitiga: "))
        luas = luas_segitiga(alas, tinggi)
        print(f"Luas segitiga adalah: {luas}")
    case _:
        print("Pilihan tidak valid")
